# %%
import pandas as pd
import sys

sys.path.append("/app")
from face_lib.datasets.arcface_ijb import IJB_aligned_images

# %%
ijb_dataset = IJB_aligned_images("/app/datasets/arcface_ijb", "IJBB")
# Out:
# >>>> Reload from backup: /app/datasets/arcface_ijb/IJBB_backup.npz ...

# %%
ijb_dataset.img_names[0]
# Out:
# 'datasets/arcface_ijb/IJBC/loose_crop/1.jpg'

# %%
len(ijb_dataset)
# Out:
# 227630

# %%
gallery_1 = pd.read_csv("/app/datasets/ijb-c/protocols/test4/gallery_G1.csv")
gallery_2 = pd.read_csv("/app/datasets/ijb-c/protocols/test4/gallery_G2.csv")
probes = pd.read_csv("/app/datasets/ijb-c/protocols/test4/probes.csv")

# %%
len(set(list(gallery_1["SUBJECT_ID"]))), len(set(list(gallery_1["TEMPLATE_ID"])))
# Out:
# (1772, 1772)

# %%
len(set(list(gallery_2["SUBJECT_ID"]))), len(set(list(gallery_2["TEMPLATE_ID"])))
# Out:
# (1759, 1759)

# %%
set(gallery_1["SUBJECT_ID"].tolist()).intersection(
    set(gallery_2["SUBJECT_ID"].tolist())
)
# Out:
# set()

# %%
len(set(probes["SUBJECT_ID"].to_list()))
# Out:
# 3531
