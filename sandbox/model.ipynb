# %%
import sys
from pytorch_lightning.cli import LightningCLI

sys.path.append("/app")
from evaluation.ijb_evals import plot_dir_far_scores
from pytorch_lightning import Trainer
from face_lib.models.scf import SphereConfidenceFace

# %%
import numpy as np

d = np.load("/app/outputs/IJB_result/IJBC_TcmNN.npz")

# %%
fig = plot_dir_far_scores(d["scores"], d["names"])

# %%
fig.savefig("f.png")

# %%
d = np.load("/app/outputs/IJB_result/IJBC_default.npz")
plot_dir_far_scores(d["scores"], d["names"]);

# %%
d["names"]
# Out:
# array(['scf_ijb_embs_IJBC'], dtype='<U17')
