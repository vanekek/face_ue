# %%
import sys
from pytorch_lightning.cli import LightningCLI
sys.path.append("/app")
from pytorch_lightning import Trainer
from face_lib.models.scf import SphereConfidenceFace

# %%
import numpy as np
d = np.load('/app/outputs/IJB_result/scf_ijb_embs_IJBC.npz')

# %%
from evaluation.ijb_evals import plot_dir_far_cmc_scores
plot_dir_far_cmc_scores(d['scores'], d['names']);

# %%
d['names']
# Out:
# array(['scf_ijb_embs_IJBC'], dtype='<U17')
