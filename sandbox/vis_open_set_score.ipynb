# %%
import sys
import seaborn as sns
import matplotlib.pyplot as plt

sys.path.append("/app")
import numpy as np

# %%
cos_sim_g1_scores = np.load(
    "/app/outputs/ijb_evals/ijb_evals_2023-06-07_08-24-25/CosineSim_gallery_1_open_set_scores.npy"
)
scf_sim_g1_scores = np.load(
    "/app/outputs/ijb_evals/ijb_evals_2023-06-07_08-42-30/SCF_gallery_1_open_set_scores.npy"
)

# %%
scf_sim_g1_scores.mean()
# Out:
# 4.255950780157162

# %%
sns.set_theme()
plt.figure(figsize=(8, 6))
# sns.distplot(
#     cos_sim_g1_scores,
#     bins=50,
#     kde=True,
#     norm_hist=True,
#     hist=True,
#     label='cos_sim_g1_scores',
# );
sns.distplot(
    scf_sim_g1_scores,
    bins=50,
    kde=True,
    norm_hist=True,
    hist=True,
    label="scf_sim_g1_scores",
);
# Out:
# /home/erlygin/miniconda/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.set_theme()
plt.figure(figsize=(8, 6))
sns.distplot(
    cos_sim_g1_scores,
    bins=50,
    kde=True,
    norm_hist=True,
    hist=True,
    label="cos_sim_g1_scores",
);
# Out:
# /home/erlygin/miniconda/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
